# %% [markdown]
# ### 1. Read and print

# %%
import pandas as pd
import numpy as np

# %%
demand = pd.read_csv(r'C:\Users\COMPUER\Desktop\demand.csv')

# %%
demand[:15]
demand.dtypes
# Out:
# City                                           object
# Mapped_Sales_Type                              object
# Mapped_Item_Code                                int64
# Transaction_Date                               object
# Quantity_Sold                                   int64
# Median_Price                                  float64
# Average_Tax_Percent                           float64
# Effective_Price                               float64
# Percent_Quantity_With_Discount                float64
# Avg_Discount_Percent_On_Discounted_Items      float64
# Year                                            int64
# Month                                           int64
# Day                                            object
# Car_sales                                     float64
# F_and_B_Inflation                             float64
# F_and_B_Inflation_Adjusted_Effective_Price    float64
# F_and_B_Inflation_Adjusted_Median_Price       float64
# ...

# %% [markdown]
# ###  2.convert transaction column to date

# %%
demand['Transaction_Date'] = pd.to_datetime(demand['Transaction_Date'])

# %%
demand.dtypes
demand[:2]

# %% [markdown]
# ### 3.	Subset the dataframe for transaction date greater than '2016-08-01'

# %%
new_sub = demand.loc[(demand['Transaction_Date'] > '2016-08-01')]

# %%
new_sub.count()
# Out:
# City                                          30192
# Mapped_Sales_Type                             30192
# Mapped_Item_Code                              30192
# Transaction_Date                              30192
# Quantity_Sold                                 30192
# Median_Price                                  30192
# Average_Tax_Percent                           30192
# Effective_Price                               30190
# Percent_Quantity_With_Discount                12198
# Avg_Discount_Percent_On_Discounted_Items      12191
# Year                                          30192
# Month                                         30192
# Day                                           30192
# Car_sales                                     30192
# F_and_B_Inflation                             30192
# F_and_B_Inflation_Adjusted_Effective_Price    30190
# F_and_B_Inflation_Adjusted_Median_Price       30192
# First_Week_Of_The_Month_Dummy                 30192
# ...

# %% [markdown]
# ### 4. Look for unique values in Mapped_Sales_Type

# %%
uni_sales_type = demand['Mapped_Sales_Type'].unique()
uni_sales_type
# Out:
# array(['Take Away', 'Main Hall', 'Express', 'Delivery', 'Dine-in',
#        'Bakery'], dtype=object)

# %% [markdown]
# ### 5. subset to perform avg and other operations

# %%
susb = demand.loc[(demand['Avg_Discount_Percent_On_Discounted_Items'] < 1.0)]
susb[:3]
# Out:
#          City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 5   Hyderabad          Delivery              4056       2018-07-31
# 10  Hyderabad          Delivery              4061       2018-07-31
# 20  Hyderabad           Dine-in               966       2018-07-31
#
#     Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 5             617         322.0                 0.05       305.354585
# 10            144         942.0                 0.05       942.631515
# 20           1250         392.0                 0.05       378.840053
#
#     Percent_Quantity_With_Discount  Avg_Discount_Percent_On_Discounted_Items  \
# 5                         0.003953                                  0.105020
# 10                        0.151515                                  0.105006
# 20                        0.003512                                  0.105008
#
#     ...  Day  Car_sales F_and_B_Inflation  \
# 5   ...  Tue    7559.28             143.7
# ...

# %%
san = susb['Avg_Discount_Percent_On_Discounted_Items'] >= 1.0
for i in san :
    if i is True :
        print('found')
print('not found')
# Out:
# not found

# %% [markdown]
# ### 6. Aggregation

# %%
susb.groupby(['City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date' ])['Quantity_Sold' ].sum()
# Out:
# City     Mapped_Sales_Type  Mapped_Item_Code  Transaction_Date
# Chennai  Delivery           4055              2017-08-04          377
#                                               2017-08-05          377
#                                               2017-08-06          638
#                                               2017-08-07          393
#                                               2017-08-08          320
#                                                                  ...
# Mumbai   Take Away          4068              2016-11-30          209
#                                               2016-12-04          403
#                                               2016-12-13          199
#                                               2016-12-29          233
#                                               2017-01-13          273
# Name: Quantity_Sold, Length: 8902, dtype: int64

# %%
susb.groupby(['City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date' ])['Median_Price' ].median()
# Out:
# City     Mapped_Sales_Type  Mapped_Item_Code  Transaction_Date
# Chennai  Delivery           4055              2017-08-04          260.0
#                                               2017-08-05          260.0
#                                               2017-08-06          260.0
#                                               2017-08-07          260.0
#                                               2017-08-08          260.0
#                                                                   ...
# Mumbai   Take Away          4068              2016-11-30          405.0
#                                               2016-12-04          405.0
#                                               2016-12-13          405.0
#                                               2016-12-29          405.0
#                                               2017-01-13          405.0
# Name: Median_Price, Length: 8902, dtype: float64

# %%
susb.groupby(['City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date' ])['Effective_Price'].median()
# Out:
# City     Mapped_Sales_Type  Mapped_Item_Code  Transaction_Date
# Chennai  Delivery           4055              2017-08-04          264.113759
#                                               2017-08-05          264.138571
#                                               2017-08-06          264.223814
#                                               2017-08-07          264.101702
#                                               2017-08-08          263.712153
#                                                                      ...
# Mumbai   Take Away          4068              2016-11-30          423.535816
#                                               2016-12-04          422.642877
#                                               2016-12-13          418.956250
#                                               2016-12-29          423.205164
#                                               2017-01-13          423.201358
# Name: Effective_Price, Length: 8902, dtype: float64

# %% [markdown]
# ### 7. Display the data for Effective_Price = not null and just print the last 5 rows

# %%
effnotnull = demand[demand.Effective_Price.notnull()]
effnotnull.tail(5)
# Out:
#          City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 30226  Mumbai         Take Away              4056       2016-08-01
# 30227  Mumbai         Take Away              4058       2016-08-01
# 30228  Mumbai           Dine-in               964       2016-08-01
# 30229  Mumbai         Take Away              4066       2016-08-01
# 30230  Mumbai          Delivery              4061       2016-08-01
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 30226            615         239.0                 0.14       232.033552
# 30227           1289         212.8                 0.14       202.575840
# 30228            140         933.0                 0.21      1063.855517
# 30229            179         501.0                 0.14       534.060000
# 30230            117         716.5                 0.15       780.810000
#
#        Percent_Quantity_With_Discount  \
# 30226                        0.013889
# 30227                        0.009338
# ...

# %% [markdown]
# ### 8. Display the data for city = Chennai AND Mapped_Sales_Type = Delivery and print top 5 records

# %%
fil = demand.loc[(demand['City'] == 'Chennai') & (demand['Mapped_Sales_Type'] == 'Delivery')  ]
fil.head(5)
# Out:
#          City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 8379  Chennai          Delivery              4055       2018-02-05
# 8384  Chennai          Delivery              4068       2018-02-05
# 8387  Chennai          Delivery              4064       2018-02-05
# 8388  Chennai          Delivery              4058       2018-02-05
# 8392  Chennai          Delivery              4061       2018-02-05
#
#       Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 8379            544        281.10                 0.05       262.502194
# 8384            129        566.43                 0.05       562.110000
# 8387            186        619.34                 0.05       617.659733
# 8388            287        259.19                 0.05       239.381307
# 8392            128        850.62                 0.05       855.697647
#
#       Percent_Quantity_With_Discount  \
# 8379                             NaN
# 8384                             NaN
# ...

# %% [markdown]
# ### 9.	Display the data for the column “Day” with values Mon, Tue and Wed

# %%
dataframe1=demand[demand[['Day']].isin(['Mon','Tue','Wed']).any(axis=1)]
(dataframe1)
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978        7/31/2018
# 1      Hyderabad         Take Away              4064        7/31/2018
# 2      Hyderabad         Main Hall               965        7/31/2018
# 3      Hyderabad           Express              9978        7/31/2018
# 4      Hyderabad           Express              1045        7/31/2018
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056       08-01-2016
# 30227     Mumbai         Take Away              4058       08-01-2016
# 30228     Mumbai           Dine-in               964       08-01-2016
# 30229     Mumbai         Take Away              4066       08-01-2016
# 30230     Mumbai          Delivery              4061       08-01-2016
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %% [markdown]
# ### 10.	Display the data for Percent_Quantity_With_Discount not equal to 0.0

# %%
demand.loc[(demand['Percent_Quantity_With_Discount'] != 0 )]
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978        7/31/2018
# 1      Hyderabad         Take Away              4064        7/31/2018
# 2      Hyderabad         Main Hall               965        7/31/2018
# 3      Hyderabad           Express              9978        7/31/2018
# 4      Hyderabad           Express              1045        7/31/2018
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056       08-01-2016
# 30227     Mumbai         Take Away              4058       08-01-2016
# 30228     Mumbai           Dine-in               964       08-01-2016
# 30229     Mumbai         Take Away              4066       08-01-2016
# 30230     Mumbai          Delivery              4061       08-01-2016
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %% [markdown]
# ### 11.	Add a column “Range” to the existing dataframe for below condition
